# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#put categorical features in df_cat
df=pd.read_csv('train.csv')
df_cat=df.select_dtypes(include='object').copy()

# %%
#now BoxPlot LandContour 
sns.boxplot(x='LandContour',y='SalePrice',data=df,dodge=False)

# %% [markdown]
# By doing this boxplot, we can visualize the effect of different values on SalePrice.<br>
# How?<br>
# Look at the distribution for all of them. <br>
# Rank them based on their median. Then HLS=4, Low=3, Lvl=2, Bnk=1.
# <br>
# In this way, we can interpret the cateogrical features into numerical equivalent and make them ready for regression works.
